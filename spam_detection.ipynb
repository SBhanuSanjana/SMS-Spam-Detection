# %%
#

# %%
# 🧠 Importing important libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, confusion_matrix

# Step 1: Import necessary libraries (if not already done)

# Step 2: Load the dataset
# Verify the file path and encoding
df = pd.read_csv('/spam (1).csv', encoding='ISO-8859-1') # or 'utf-8', 'latin-1'

# Step 3: Keep only the relevant columns
# Ensure 'v1' and 'v2' are the correct columns for label and message
df = df[['v1', 'v2']]  # Update column names if necessary

# Step 4: Rename the columns for better readability
df.columns = ['label', 'message']

# Step 5: Display the first few rows of the data
df.head()
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
# Step 1: Import necessary libraries (if not already done)
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Step 1: Split the data
X = df['message']
y = df['label']

# Step 2: Convert text to numeric using TF-IDF
vectorizer = TfidfVectorizer()
X_vectorized = vectorizer.fit_transform(X)

# Step 3: Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_vectorized, y, test_size=0.2, random_state=42)

# Step 4: Train a Naive Bayes classifier
model = MultinomialNB()
model.fit(X_train, y_train)

# Step 5: Predict on test set
y_pred = model.predict(X_test)

# Step 6: Print accuracy and other metrics
print("✅ Accuracy:", accuracy_score(y_test, y_pred))
print("\n🔍 Classification Report:\n", classification_report(y_test, y_pred))
print("\n📊 Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# ✅ Accuracy: 0.9623318385650225
#
# 🔍 Classification Report:
#                precision    recall  f1-score   support
#
#          ham       0.96      1.00      0.98       965
#         spam       1.00      0.72      0.84       150
#
#     accuracy                           0.96      1115
#    macro avg       0.98      0.86      0.91      1115
# weighted avg       0.96      0.96      0.96      1115
#
#
# 📊 Confusion Matrix:
#  [[965   0]
#  [ 42 108]]

# %%
def predict_message(message):
    data = [message]
    vectorized_data = vectorizer.transform(data)
    prediction = model.predict(vectorized_data)
    return prediction[0]

# Example test
test_msg = "Your OTP is 987654. Do not share it with anyone."
result = predict_message(test_msg)
print("📩 Message:", test_msg)
print("🧠 Prediction:", result)
# Out:
# 📩 Message: Your OTP is 987654. Do not share it with anyone.
# 🧠 Prediction: ham
